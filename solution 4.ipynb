# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# * route to show the following details:
# * Company Name: ABC Corporation
# * Location: India
# * Contact Detail: 999-999-9999

# %%
from flask import Flask

# %%
app = Flask(__name__)

# %%
@app.route("/welcome")
def message():
    return "ABC Corporation, India, 999-999-9999"

# %%
if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://192.168.0.103:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [19/Feb/2023 21:34:44] "GET /welcome HTTP/1.1" 200 -

# %% [markdown]
# ![Screenshot%202023-02-19%20213458.jpg](attachment:Screenshot%202023-02-19%20213458.jpg)
